# %% [markdown]
# # Importing modules

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

print('Modules imported')
# Out:
# Modules imported

# %% [markdown]
# ## Importing covid19 dataset

# %%
corona_dataset_csv = pd.read_csv('Datasets/time_series_covid19_confirmed_global.csv')

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region       Lat        Long  \
# 0                           NaN          Afghanistan  33.93911   67.709953
# 1                           NaN              Albania  41.15330   20.168300
# 2                           NaN              Algeria  28.03390    1.659600
# 3                           NaN              Andorra  42.50630    1.521800
# 4                           NaN               Angola -11.20270   17.873900
# 5                           NaN  Antigua and Barbuda  17.06080  -61.796400
# 6                           NaN            Argentina -38.41610  -63.616700
# 7                           NaN              Armenia  40.06910   45.038200
# 8  Australian Capital Territory            Australia -35.47350  149.012400
# 9               New South Wales            Australia -33.86880  151.209300
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  ...  11/15/20  \
# ...

# %%
corona_dataset_csv.shape
# Out:
# (271, 312)

# %% [markdown]
# ## Deleting useless columns

# %%
corona_dataset_csv.drop(['Lat', 'Long'], axis = 1, inplace = True)

# %%
corona_dataset_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  11/15/20  \
# 0        0        0        0        0        0        0  ...     43240
# ...

# %% [markdown]
# ## Aggregating rows by country

# %%
corona_dataset_aggregated = corona_dataset_csv.groupby('Country/Region').sum()

# %%
corona_dataset_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  11/15/20  \
# Country/Region                                           ...
# ...

# %%
corona_dataset_aggregated.shape
# Out:
# (191, 308)

# %% [markdown]
# ## Visualizing data for country

# %%
corona_dataset_aggregated.loc['China'].plot()
corona_dataset_aggregated.loc['Italy'].plot()
corona_dataset_aggregated.loc['Spain'].plot()
plt.legend()

# %% [markdown]
# ## Calculating a good measure

# %%
corona_dataset_aggregated.loc['China'].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Calculating the first derivative of the curve

# %%
corona_dataset_aggregated.loc['China'].diff().plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Calculating maximum infection rate for China

# %%
corona_dataset_aggregated.loc['China'].diff().max()
# Out:
# 15136.0

# %% [markdown]
# ## Calculating maximum infection rate for all countries

# %%
countries = list(corona_dataset_aggregated.index)
maximum_infection_rates = []
for country in countries:
    maximum_infection_rates.append(corona_dataset_aggregated.loc[country].diff().max())
corona_dataset_aggregated['Maximum Infection Rate'] = maximum_infection_rates

# %%
corona_dataset_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  11/16/20  11/17/20  11/18/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     43403     43628     43851
# Albania               0        0        0  ...     28432     29126     29837
# Algeria               0        0        0  ...     68589     69591     70629
# Andorra               0        0        0  ...      5914      5951      6018
# ...

# %% [markdown]
# ## New dataframe with only needed column

# %%
corona_data = pd.DataFrame(corona_dataset_aggregated['Maximum Infection Rate'])

# %%
corona_data.head()
# Out:
#                 Maximum Infection Rate
# Country/Region
# Afghanistan                      915.0
# Albania                          836.0
# Algeria                         1133.0
# Andorra                          299.0
# Angola                           355.0

# %% [markdown]
# ## Importing happiness dataset

# %%
world_happiness_report = pd.read_csv('Datasets/World Happiness Report.csv')
world_happiness_report.head()
# Out:
#        Country  Happiness Rank  Happiness Score   Economy    Family    Health  \
# 0       Norway               1            7.537  1.616463  1.533524  0.796667
# 1      Denmark               2            7.522  1.482383  1.551122  0.792566
# 2      Iceland               3            7.504  1.480633  1.610574  0.833552
# 3  Switzerland               4            7.494  1.564980  1.516912  0.858131
# 4      Finland               5            7.469  1.443572  1.540247  0.809158
#
#     Freedom  Generosity  Corruption  Dystopia  Job Satisfaction  \
# 0  0.635423    0.362012    0.315964  2.277027              94.6
# 1  0.626007    0.355280    0.400770  2.313707              93.5
# 2  0.627163    0.475540    0.153527  2.322715              94.5
# 3  0.620071    0.290549    0.367007  2.276716              93.7
# 4  0.617951    0.245483    0.382612  2.430182              91.2
#
#            Region
# 0  Western Europe
# 1  Western Europe
# 2  Western Europe
# 3  Western Europe
# ...

# %%
world_happiness_report.shape
# Out:
# (153, 12)

# %% [markdown]
# ## Removing useless columns

# %%
columns_to_drop = ['Happiness Rank', 'Happiness Score', 'Generosity', 'Region']
world_happiness_report.drop(columns_to_drop, axis = 1, inplace = True)

# %%
world_happiness_report.head()
# Out:
#        Country   Economy    Family    Health   Freedom  Corruption  Dystopia  \
# 0       Norway  1.616463  1.533524  0.796667  0.635423    0.315964  2.277027
# 1      Denmark  1.482383  1.551122  0.792566  0.626007    0.400770  2.313707
# 2      Iceland  1.480633  1.610574  0.833552  0.627163    0.153527  2.322715
# 3  Switzerland  1.564980  1.516912  0.858131  0.620071    0.367007  2.276716
# 4      Finland  1.443572  1.540247  0.809158  0.617951    0.382612  2.430182
#
#    Job Satisfaction
# 0              94.6
# 1              93.5
# 2              94.5
# 3              93.7
# 4              91.2

# %% [markdown]
# ## Changing the indices of the dataframe

# %%
world_happiness_report.set_index(['Country'], inplace = True)
world_happiness_report.head()
# Out:
#               Economy    Family    Health   Freedom  Corruption  Dystopia  \
# Country
# Norway       1.616463  1.533524  0.796667  0.635423    0.315964  2.277027
# Denmark      1.482383  1.551122  0.792566  0.626007    0.400770  2.313707
# Iceland      1.480633  1.610574  0.833552  0.627163    0.153527  2.322715
# Switzerland  1.564980  1.516912  0.858131  0.620071    0.367007  2.276716
# Finland      1.443572  1.540247  0.809158  0.617951    0.382612  2.430182
#
#              Job Satisfaction
# Country
# Norway                   94.6
# Denmark                  93.5
# Iceland                  94.5
# Switzerland              93.7
# Finland                  91.2

# %% [markdown]
# ## Joining datasets

# %% [markdown]
# ### Corona dataset:

# %%
corona_data.head()
# Out:
#                 Maximum Infection Rate
# Country/Region
# Afghanistan                      915.0
# Albania                          836.0
# Algeria                         1133.0
# Andorra                          299.0
# Angola                           355.0

# %% [markdown]
# ### World Happiness Dataset:

# %%
world_happiness_report.head()
# Out:
#               Economy    Family    Health   Freedom  Corruption  Dystopia  \
# Country
# Norway       1.616463  1.533524  0.796667  0.635423    0.315964  2.277027
# Denmark      1.482383  1.551122  0.792566  0.626007    0.400770  2.313707
# Iceland      1.480633  1.610574  0.833552  0.627163    0.153527  2.322715
# Switzerland  1.564980  1.516912  0.858131  0.620071    0.367007  2.276716
# Finland      1.443572  1.540247  0.809158  0.617951    0.382612  2.430182
#
#              Job Satisfaction
# Country
# Norway                   94.6
# Denmark                  93.5
# Iceland                  94.5
# Switzerland              93.7
# Finland                  91.2

# %%
data = world_happiness_report.join(corona_data).copy()
data.head()
# Out:
#               Economy    Family    Health   Freedom  Corruption  Dystopia  \
# Country
# Norway       1.616463  1.533524  0.796667  0.635423    0.315964  2.277027
# Denmark      1.482383  1.551122  0.792566  0.626007    0.400770  2.313707
# Iceland      1.480633  1.610574  0.833552  0.627163    0.153527  2.322715
# Switzerland  1.564980  1.516912  0.858131  0.620071    0.367007  2.276716
# Finland      1.443572  1.540247  0.809158  0.617951    0.382612  2.430182
#
#              Job Satisfaction  Maximum Infection Rate
# Country
# Norway                   94.6                  1680.0
# Denmark                  93.5                  1427.0
# Iceland                  94.5                   106.0
# Switzerland              93.7                 21926.0
# Finland                  91.2                   469.0

# %% [markdown]
# ### Correlation Matrix

# %%
data.corr()
# Out:
#                          Economy    Family    Health   Freedom  Corruption  \
# Economy                 1.000000  0.688701  0.841900  0.375043    0.357817
# Family                  0.688701  1.000000  0.612003  0.425937    0.233749
# Health                  0.841900  0.612003  1.000000  0.354683    0.285952
# Freedom                 0.375043  0.425937  0.354683  1.000000    0.497729
# Corruption              0.357817  0.233749  0.285952  0.497729    1.000000
# Dystopia                0.018464  0.073697  0.049716  0.089590   -0.016260
# Job Satisfaction        0.700662  0.623266  0.704795  0.500655    0.337131
# Maximum Infection Rate  0.234333  0.157444  0.263917  0.092229    0.018160
#
#                         Dystopia  Job Satisfaction  Maximum Infection Rate
# Economy                 0.018464          0.700662                0.234333
# Family                  0.073697          0.623266                0.157444
# ...

# %% [markdown]
# ## Visualization of results

# %%
data.head()
# Out:
#               Economy    Family    Health   Freedom  Corruption  Dystopia  \
# Country
# Norway       1.616463  1.533524  0.796667  0.635423    0.315964  2.277027
# Denmark      1.482383  1.551122  0.792566  0.626007    0.400770  2.313707
# Iceland      1.480633  1.610574  0.833552  0.627163    0.153527  2.322715
# Switzerland  1.564980  1.516912  0.858131  0.620071    0.367007  2.276716
# Finland      1.443572  1.540247  0.809158  0.617951    0.382612  2.430182
#
#              Job Satisfaction  Maximum Infection Rate
# Country
# Norway                   94.6                  1680.0
# Denmark                  93.5                  1427.0
# Iceland                  94.5                   106.0
# Switzerland              93.7                 21926.0
# Finland                  91.2                   469.0

# %% [markdown]
# ### Plotting Economy vs Maximum Infection Rate

# %%
splot = sns.scatterplot(data = data, x = "Economy", y = "Maximum Infection Rate")
splot.set_yscale("log")

# %%
rplot = sns.regplot(data = data, x = "Economy", y = "Maximum Infection Rate")
rplot.set_yscale("log")

# %% [markdown]
# ### Plotting Family vs Maximum Infection Rate

# %%
splot = sns.scatterplot(data = data, x = "Family", y = "Maximum Infection Rate")
splot.set_yscale("log")

# %%
rplot = sns.regplot(data = data, x = "Family", y = "Maximum Infection Rate")
rplot.set_yscale("log")

# %% [markdown]
# ### Plotting Health vs Maximum Infection Rate

# %%
splot = sns.scatterplot(data = data, x = "Health", y = "Maximum Infection Rate")
splot.set_yscale("log")

# %%
rplot = sns.regplot(data = data, x = "Health", y = "Maximum Infection Rate")
rplot.set_yscale("log")

# %% [markdown]
# ### Plotting Freedom vs Maximum Infection Rate

# %%
splot = sns.scatterplot(data = data, x = "Freedom", y = "Maximum Infection Rate")
splot.set_yscale("log")

# %%
rplot = sns.regplot(data = data, x = "Freedom", y = "Maximum Infection Rate")
rplot.set_yscale("log")

# %% [markdown]
# ### Plotting Corruption vs Maximum Infection Rate

# %%
splot = sns.scatterplot(data = data, x = "Corruption", y = "Maximum Infection Rate")
splot.set_yscale("log")

# %%
rplot = sns.regplot(data = data, x = "Corruption", y = "Maximum Infection Rate")
rplot.set_yscale("log")

# %% [markdown]
# ### Plotting Dystopia vs Maximum Infection Rate

# %%
splot = sns.scatterplot(data = data, x = "Dystopia", y = "Maximum Infection Rate")
splot.set_yscale("log")

# %%
rplot = sns.regplot(data = data, x = "Dystopia", y = "Maximum Infection Rate")
rplot.set_yscale("log")

# %% [markdown]
# ### Plotting Job Satisfaction vs Maximum Infection Rate

# %%
splot = sns.scatterplot(data = data, x = 'Job Satisfaction', y = 'Maximum Infection Rate')
splot.set_yscale("log")

# %%
rplot = sns.regplot(data = data, x = 'Job Satisfaction', y = 'Maximum Infection Rate')
rplot.set_yscale("log")
